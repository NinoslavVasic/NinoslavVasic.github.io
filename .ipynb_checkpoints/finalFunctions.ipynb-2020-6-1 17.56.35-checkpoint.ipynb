# %%
import requests 
import json 
from bs4 import BeautifulSoup
import pandas as pd 
import numpy as np
import re 
from nltk.corpus import reuters, stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

# %%
def cleanhtml(raw_html):
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', raw_html)
    return cleantext

# %%
def process_text(doc):
    doc = cleanhtml(str(doc))
    sw = set(stopwords.words('english'))#set of default stopwords
    sw_addon= {'ul', 'itemscope', 'repeatli', 'itemscope', 'repeatspan', 'itempropcpcs','itempropcpcs',
              'itempropcodegspanspan','itempropdescriptionphysicsspanlili', 'li'}
    regex = re.compile('[^a-zA-Z ]')#compile all non-letter character
    re_clean = regex.sub('', doc)# substitute all non-letter characters
    words = word_tokenize(re_clean)# break down articles into words
    words = [lemmatizer.lemmatize(word) for word in words]# lemmatize each word
    output = [word.lower() for word in words if word.lower() not in sw.union(sw_addon)]# list of words not part of sw
    output = ' '.join(output)
    return output

def getClaims(soup):
    claim = soup.findAll(class_ = 'claim-text')
    return pd.Series(process_text(claim))

def getDescription(soup):
    description = soup.findAll(class_ = 'description')
    return pd.Series(process_text(description))

def getClassification(soup):
    classification = soup.findAll(itemprop = 'cpcs')
    return pd.Series(process_text(classification))

def getCitations(soup): 
    a = len(soup.findAll(itemprop = 'forwardReferencesOrig'))
    b = len(soup.findAll(itemprop="forwardReferencesFamily"))
    return pd.Series(a + b)


data = pd.read_csv('pricingData.csv')

links_a = pd.Series(data['Patent No. Hyperlink']).dropna()
links_b = pd.Series(data['Publication No. Hyperlink']).dropna()

links = links_a.append(links_b)


columns = ['Citations', 'Description', 'Classification', 'Claims']

#finalDF = pd.DataFrame(columns = columns, index = range(135))
finalDF = pd.DataFrame(columns = columns)

index = 0 
for link in links:
    url = link
    result = requests.get(url)
    html = result.text
    soup = BeautifulSoup(html,'lxml')
    df = pd.DataFrame({
        'Citations' : getCitations(soup),
        'Description' : getDescription(soup),
        'Classification' : getClassification(soup),
        'Claims' : getClaims(soup)
    })
    finalDF = pd.concat([finalDF, df])

# %%
finalDF
# Out:
#    Citations                                        Description  \
# 0         12  applicant hereby claim priority provisional pa...
# 0         15  background inventionthe present invention rela...
# 0         24  field inventionthe present invention relates e...
# 0         53  related applicationsthis application claim pri...
# 0          4  background invention field inventionthe presen...
# ..       ...                                                ...
# 0          8  related applications application continuation ...
# 0          7  cross reference related application patent app...
# 0         30  crossreference related applications patent app...
# 0         58  claim benefit prior applications present appli...
# 0          5  crossreference related applications patent app...
#
#                                        Classification  \
# 0   gphysicsgmeasuring testinggsradio directionfin...
# 0   gphysicsgcomputing calculating countinggfelect...
# 0   gphysicsgcomputing calculating countinggqdata ...
# 0   gphysicsgcomputing calculating countinggqdata ...
# 0   gphysicsgcomputing calculating countinggqdata ...
# ..                                                ...
# 0   gf gf gphysicsgcomputing calculating countingg...
# 0   gf gf gphysicsgcomputing calculating countingg...
# 0   helectricityhelectric communication techniqueh...
# 0   helectricityhelectric communication techniqueh...
# 0   helectricityhelectric communication techniqueh...
#
#                                                Claims
# 0   positioning system comprising first correlatio...
# 0   system finding trading ad network comprisinga ...
# 0   method performed computer server establishing ...
# 0   method marketing marketable entity selected gr...
# 0   userconcerned information provision system com...
# ..                                                ...
# 0   data synchronisation system comprisinga data s...
# 0   method comprisingsending request network serve...
# 0   system transmitting talking replay electronic ...
# 0   canceled device locationbased authentication u...
# 0   computerimplemented method providing second co...
#
# [132 rows x 4 columns]

# %%
df.iloc[0,1]
# Out:
# 'crossreference related applications patent application continuation us patent application ser filed jun entitled method system delivery content communication networks continuation us patent application ser filed jan entitled system method augmenting rich media content using multiple content repositories entirety herein incorporated reference technical field present disclosure relates generally content distribution specifically computerimplemented system method enabling augmenting content traditionally delivered broadcast medium background traditional broadcast medium ie content bound television radio delivered audience channel terrestrial radio satellite coax fiberoptic cable delivered within context schedule eg radio programming schedule television broadcast schedule convention content item eg television episode movie radio program scheduled fit within time slot begin end either top bottom hour eg conforming convention broadcaster ie company transmit delivery broadcast medium attract viewer one time slot watching content another broadcaster another time slot following broadcast schedule convention allows viewer broadcast content experience tremendous amount fluidity way content consumed instance viewer consume content multiple broadcaster day conforming convention number scheduling conflict reduced discrete number time slot furthermore multiple well defined timeslots broadcaster ha ability deliver broad menu content potential viewer contrary existence time slot individual unit artistic expression ie broadcast content sometimes produced block larger time slot available broadcast furthermore many broadcaster require broadcast content shortened even smaller block eg minute hour slot minute hour slot interstitial advertisement ie commercial inserted content make delivery commercially viable broadcaster discrepancy original runtime broadcast content time available broadcast schedule generally result element broadcast content trimmed delivery broadcast medium order overcome limitation traditional broadcast schedule creator broadcast content often make additional content available broadcast audience uploading additional medium asset website republishing additional medium asset via alternate mean eg selling show dvd internet medium outlet approach requires audience perform additional manual action eg go website sign account internet medium outlet download file buy copy medium asset ha packaged commercial sale performed audience percentage time approach limited audience often perform action get additional medium asset later time eg computer store barrier immediacy also reduces percentage audience finally gain access additional content broad availability home medium device store broadcast content later playback eg vcrs dvrs home medium center etc audience way consume broadcast outside predefined broadcast schedule allows broadcast audience begin consumption broadcast content time different time wa originally scheduled broadcast eg recording tv show one day playing another recording movie playing afternoon viewer work played viewer return home evening scheduling series recording played back audience member return vacation many home medium device offer function allow broadcast audience fastforward replay pause broadcast content function allow broadcast audience cause runtime runtime content modified original scheduled runtime result technology allow audience longer constrained broadcast schedule still ability consume broadcast content even availability home medium device broadcast content continues delivered within context broadcast schedule mean even though home medium device available storing content consumption outside predefined schedule content consumed remains format predefined schedule additionally savvy internet user may able find content scheduled home medium device record presented another context eg website part subscription service earlier time day would available use broadcast provider alone case user constrained broadcast  ...

# %%
finalDF.to_csv('draftDF.csv')
